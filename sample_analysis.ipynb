# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WorldCups.csv')
df.head(3)
# Out:
#    Year  Country   Winner      Runners-Up    Third      Fourth  GoalsScored  \
# 0  1930  Uruguay  Uruguay       Argentina      USA  Yugoslavia           70
# 1  1934    Italy    Italy  Czechoslovakia  Germany     Austria           70
# 2  1938   France    Italy         Hungary   Brazil      Sweden           84
#
#    QualifiedTeams  MatchesPlayed Attendance
# 0              13             18    590.549
# 1              16             17    363.000
# 2              15             18    375.700

# %%
# Create the "Won" column
df['Won'] = (df['Host'] == df['Winner'])

# Create the new dataframe with only the specified columns
new_df = df[['Year', 'Host', 'Won']]

new_df
# Out:
#     Year          Host    Won
# 0   1930       Uruguay   True
# 1   1934         Italy   True
# 2   1938        France  False
# 3   1950        Brazil  False
# 4   1954   Switzerland  False
# 5   1958        Sweden  False
# 6   1962         Chile  False
# 7   1966       England   True
# 8   1970        Mexico  False
# 9   1974       Germany  False
# 10  1978     Argentina   True
# 11  1982         Spain  False
# 12  1986        Mexico  False
# 13  1990         Italy  False
# 14  1994           USA  False
# 15  1998        France   True
# 16  2002   Korea/Japan  False
# 17  2006       Germany  False
# 18  2010  South Africa  False
# 19  2014        Brazil  False

# %%
sns.heatmap(new_df[["Year", "Won"]])
# Out:
# <Axes: >
